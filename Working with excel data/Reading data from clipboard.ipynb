# %% [markdown]
# Open page https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)_per_capita
#
# Select data from table "List of per capita nominal GDP for countries and dependencies"
#
# Press "Ctrl+C"

# %%
import pandas as pd

frame_from_clipboard = pd.read_clipboard()

frame_from_clipboard.head(5)
# Out:
#   International Monetary Fund (2016)[4] World Bank (2015)[5]  \
# 0                                  Rank              Country
# 1                                     1           Luxembourg
# 2                                     2          Switzerland
# 3                                     3               Norway
# 4                                     —                Macau
#
#   United Nations (2015)[6]
# 0                      US$
# 1                  103,199
# 2                   79,242
# 3                   70,392
# 4                   67,079

# %%
frame_from_clipboard.columns = frame_from_clipboard.iloc[0]

# %%
frame_from_clipboard.head(10)
# Out:
# International Monetary Fund (2016)[4]  Rank         Country      US$
# 0                                      Rank         Country      US$
# 1                                         1      Luxembourg  103,199
# 2                                         2     Switzerland   79,242
# 3                                         3          Norway   70,392
# 4                                         —           Macau   67,079
# 5                                         4         Ireland   62,562
# 6                                         5           Qatar   60,787
# 7                                         6         Iceland   59,629
# 8                                         7   United States   57,436
# 9                                         8         Denmark   53,744

# %%
frame_from_clipboard.reindex(frame_from_clipboard.index.drop(0))
# Out:
# International Monetary Fund (2016)[4] Rank  \
# 1                                        1
# 2                                        2
# 3                                        3
# 4                                        —
# 5                                        4
# 6                                        5
# 7                                        6
# 8                                        7
# 9                                        8
# 10                                       9
# 11                                      10
# 12                                      11
# 13                                      12
# 14                                      13
# 15                                      14
# 16                                       —
# 17                                      15
# 18                                      16
# 19                                      17
# 20                                      18
# 21                                      19
# ...
